# %%
# !nvidia-smi
# Out:
# Sat Sep 19 02:38:28 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# check nvcc
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Fri_Feb_21_20:23:50_PST_2025
# Cuda compilation tools, release 12.8, V12.8.93
# Build cuda_12.8.r12.8/compiler.35583870_0

# %%
# check cuFFT
# !find /usr -name "libcufft*" 2>/dev/null | head -20
# Out:
# /usr/share/doc/libcufft-dev-12-8
# /usr/share/doc/libcufft-12-8
# /usr/local/lib/python3.13/dist-packages/nvidia/cufft/lib/libcufftw.so.11
# /usr/local/lib/python3.13/dist-packages/nvidia/cufft/lib/libcufft.so.11
# /usr/local/cuda-12.8/targets/x86_64-linux/lib/stubs/libcufft.so
# /usr/local/cuda-12.8/targets/x86_64-linux/lib/stubs/libcufftw.so
# /usr/local/cuda-12.8/targets/x86_64-linux/lib/libcufft.so
# /usr/local/cuda-12.8/targets/x86_64-linux/lib/libcufft_static.a
# /usr/local/cuda-12.8/targets/x86_64-linux/lib/libcufftw.so
# /usr/local/cuda-12.8/targets/x86_64-linux/lib/libcufftw_static.a
# /usr/local/cuda-12.8/targets/x86_64-linux/lib/libcufft_static_nocallback.a
# /usr/local/cuda-12.8/targets/x86_64-linux/lib/libcufft.so.11.3.3.83
# /usr/local/cuda-12.8/targets/x86_64-linux/lib/libcufftw.so.11.3.3.83
# /usr/local/cuda-12.8/targets/x86_64-linux/lib/libcufftw.so.11
# /usr/local/cuda-12.8/targets/x86_64-linux/lib/libcufft.so.11

# %%
# !git clone https://github.com/Wang6409/18647_hw1.git /content/18647_hw1
# Out:
# Cloning into '/content/18647_hw1'...
# remote: Enumerating objects: 146, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 146 (delta 58), reused 118 (delta 41), pack-reused 0 (from 0)
# Receiving objects: 100% (146/146), 201.92 KiB | 1.11 MiB/s, done.
# Resolving deltas: 100% (58/58), done.

# %%
# %cd /content/18647_hw1
# !git pull origin main
# Out:
# /content/18647_hw1

# %%
# !pip install -r requirements.txt

# %%
# !mkdir -p runs plots

# %%
# !cd /content/18647_hw1
# !make -C src/part3_cuda clean
# !make -C src/part3_cuda
# Out:
# make: Entering directory '/content/18647_hw1/src/part3_cuda'
# rm -f fft_multiply
# make: Leaving directory '/content/18647_hw1/src/part3_cuda'
# make: Entering directory '/content/18647_hw1/src/part3_cuda'
# nvcc -O2 -std=c++17 -o fft_multiply main.cu bigint_fft.cu utils.cu -lcufft
# nvcc warning : Support for offline compilation for architectures prior to '<compute/sm/lto>_75' will be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# make: Leaving directory '/content/18647_hw1/src/part3_cuda'

# %%
# !make -C src/part3_cuda
# !mkdir -p runs
# !src/part3_cuda/fft_multiply \
    --max-length 8 \
    --output runs/part3_smoke.csv
# !cat runs/part3_smoke.csv
# Out:
# make: Entering directory '/content/18647_hw1/src/part3_cuda'
# make: 'fft_multiply' is up to date.
# make: Leaving directory '/content/18647_hw1/src/part3_cuda'
# 1,17.281,595.743
# 2,0.0456,26.6694
# 4,0.04304,27.4074
# 8,0.041504,28.5825
# n,gpu_time_ms,total_ms,status
# 1,17.281,595.743,success
# 2,0.0456,26.6694,success
# 4,0.04304,27.4074,success
# 8,0.041504,28.5825,success

# %%
# !bash src/part3_cuda/run_colab.sh

# %%
# !bash src/part3_cuda/run_colab.sh 2>&1 | tee runs/part3_colab_manual.log
# Out:
# Sat Sep 19 02:38:52 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   63C    P0             31W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !cat runs/gpu_results.csv
# Out:
# n,gpu_time_ms,total_ms,status
# 1,0.22256,345.995,success
# 2,0.035328,4.04979,success
# 4,0.034432,0.869464,success
# 8,0.03424,2.09032,success
# 16,0.060128,68.9758,success
# 32,0.04912,35.3112,success
# 64,0.051296,110.711,success
# 128,0.065536,150.358,success
# 256,0.072032,139.015,success
# 512,0.12288,245.431,success
# 1024,0.217088,362.05,success
# 2048,0.62224,542.447,success
# 4096,1.42186,138.437,success
# 8192,0.469504,6.23438,success
# 16384,0.474208,2.36124,success
# 32768,0.488224,3.84828,success
# 65536,1.49424,7.25785,success
# 131072,2.33158,16.7373,success
# 262144,4.86838,34.925,success
# 524288,10.1457,71.679,success
# 1048576,17.8606,145.823,success
# 2097152,34.5004,297.831,success
# 4194304,67.6266,626.936,success
# 8388608,132.039,1254.35,success
# 16777216,152.408,2433.53,success
# 33554432,393.449,5560.96,success
# 67108864,,,oom:insufficient host memory for next problem size

# %%
# !nvidia-smi > runs/part3_environment.txt
# !echo "----- CUDA compiler -----" >> runs/part3_environment.txt
# !nvcc --version >> runs/part3_environment.txt
# !echo "----- CPU -----" >> runs/part3_environment.txt
# !lscpu >> runs/part3_environment.txt

# %%
# !find runs plots -maxdepth 1 -type f -print
# Out:
# runs/merged_results.csv
# runs/gpu_fft_table.csv
# runs/ece_part2.log
# runs/part3_colab.log
# runs/part3_smoke.csv
# runs/n2_table.csv
# runs/part3_environment.txt
# runs/part3_colab_manual.log
# runs/ec2_results.csv
# runs/fft_table.csv
# runs/gpu_results.csv
# runs/ece_results.csv
# runs/ec2_part2.log
# plots/fft_mops.png
# plots/gpu_fft_mops.pdf
# plots/n2_mops.png

# %%
# !zip -r /content/part3_colab_results.zip \
    src/part3_cuda \
    runs \
    plots \
    README.md
# Out:
#   adding: src/part3_cuda/ (stored 0%)
#   adding: src/part3_cuda/utils.h (deflated 40%)
#   adding: src/part3_cuda/__pycache__/ (stored 0%)
#   adding: src/part3_cuda/__pycache__/plot_results.cpython-312.pyc (deflated 46%)
#   adding: src/part3_cuda/utils.cu (deflated 62%)
#   adding: src/part3_cuda/bigint_fft.h (deflated 35%)
#   adding: src/part3_cuda/Makefile (deflated 20%)
#   adding: src/part3_cuda/bigint_fft.cu (deflated 71%)
#   adding: src/part3_cuda/run_colab.sh (deflated 54%)
#   adding: src/part3_cuda/fft_multiply (deflated 69%)
#   adding: src/part3_cuda/plot_results.py (deflated 60%)
#   adding: src/part3_cuda/main.cu (deflated 66%)
#   adding: runs/ (stored 0%)
#   adding: runs/merged_results.csv (deflated 49%)
#   adding: runs/gpu_fft_table.csv (deflated 52%)
#   adding: runs/ece_part2.log (deflated 83%)
#   adding: runs/part3_colab.log (deflated 66%)
#   adding: runs/part3_smoke.csv (deflated 32%)
#   adding: runs/n2_table.csv (deflated 44%)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/part3_colab_results.zip \
    /content/drive/MyDrive/
